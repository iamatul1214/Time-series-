# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
df=pdr.get_data_yahoo('TSLA')
df
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...                ...         ...         ...         ...         ...
# 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500.0
# 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#              Adj Close
# Date
# 2017-02-27   49.245998
# 2017-02-28   49.998001
# 2017-03-01   50.004002
# ...

# %%
## df is the data frame
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.tail(10)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2022-02-11  915.960022  850.700012  909.630005  860.000000  26492700.0
# 2022-02-14  898.880005  853.150024  861.570007  875.760010  22585500.0
# 2022-02-15  923.000000  893.380005  900.000000  922.429993  19216500.0
# 2022-02-16  926.429993  901.210022  914.049988  923.390015  17098100.0
# 2022-02-17  918.500000  874.099976  913.260010  876.349976  18392800.0
# 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500.0
# 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#              Adj Close
# Date
# 2022-02-11  860.000000
# 2022-02-14  875.760010
# 2022-02-15  922.429993
# 2022-02-16  923.390015
# 2022-02-17  876.349976
# 2022-02-18  856.979980
# ...

# %%
## So we understood that the data is from 2017 till date
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## let's try to plot only the High
df['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## Let's increase the size
df['High'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## Lets try to apply xlimit and ylimit
df['High'].plot(xlim=['2020-01-01','2021-09-09'], ylim=[0,900], figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## Lets try to apply xlimit, ylimit, coloring, line styles
df['High'].plot(xlim=['2020-01-01','2021-09-09'], ylim=[0,900], figsize=(12,5), linestyle=':', color='red')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## In time series data the index of the dataset is date. for eg-:
df.index
# Out:
# DatetimeIndex(['2017-02-27', '2017-02-28', '2017-03-01', '2017-03-02',
#                '2017-03-03', '2017-03-06', '2017-03-07', '2017-03-08',
#                '2017-03-09', '2017-03-10',
#                ...
#                '2022-02-11', '2022-02-14', '2022-02-15', '2022-02-16',
#                '2022-02-17', '2022-02-18', '2022-02-22', '2022-02-23',
#                '2022-02-24', '2022-02-25'],
#               dtype='datetime64[ns]', name='Date', length=1260, freq=None)

# %%
## Let's try to get the indexes between or xlim and ylim defined above
index=df.loc['2020-01-01':'2021-09-09'].index
share_open=df.loc['2020-01-01':'2021-09-09']['Open']

# %%
share_open
# Out:
# Date
# 2020-01-02     84.900002
# 2020-01-03     88.099998
# 2020-01-06     88.094002
# 2020-01-07     92.279999
# 2020-01-08     94.739998
#                  ...
# 2021-09-02    734.500000
# 2021-09-03    732.250000
# 2021-09-07    740.000000
# 2021-09-08    761.580017
# 2021-09-09    753.409973
# Name: Open, Length: 426, dtype: float64

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-26', '2021-08-27', '2021-08-30', '2021-08-31',
#                '2021-09-01', '2021-09-02', '2021-09-03', '2021-09-07',
#                '2021-09-08', '2021-09-09'],
#               dtype='datetime64[ns]', name='Date', length=426, freq=None)

# %%
## Let's now try to create subplots and different other varieties of plots.
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure, axis=plt.subplots()
plt.tight_layout()
figure.autofmt_xdate()
axis.plot(index, share_open)

# %% [markdown]
# ### Now lets look into Datetime Index

# %% [markdown]
# ### Whenever we have time series dataset, we know that date plays an important factor. So what we do is if the index for dataset is by default given as date, then we try to exclude it from indexing and create a separate column out of it. Moreover the datatype of date column can be object sometimes, so we should change it to datetime type.

# %%
df.reset_index()
# Out:
#            Date        High         Low        Open       Close      Volume  \
# 0    2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 1    2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2    2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 3    2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 4    2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...         ...         ...         ...         ...         ...         ...
# 1255 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500.0
# 1256 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 1257 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 1258 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 1259 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#        Adj Close
# 0      49.245998
# 1      49.998001
# ...

# %%
df_testla=df.reset_index()
df_testla
# Out:
#            Date        High         Low        Open       Close      Volume  \
# 0    2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 1    2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2    2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 3    2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 4    2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...         ...         ...         ...         ...         ...         ...
# 1255 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500.0
# 1256 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 1257 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 1258 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 1259 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#        Adj Close
# 0      49.245998
# 1      49.998001
# ...

# %%
df_testla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1260 non-null   datetime64[ns]
#  1   High       1260 non-null   float64
#  2   Low        1260 non-null   float64
#  3   Open       1260 non-null   float64
#  4   Close      1260 non-null   float64
#  5   Volume     1260 non-null   float64
#  6   Adj Close  1260 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %% [markdown]
# #### Here we have date column into datetime type so we don't need to convert it. If it was object type then we would have converted it into datetime type.

# %%
## for eg-
pd.to_datetime(df_testla['Date'])
# Out:
# 0      2017-02-27
# 1      2017-02-28
# 2      2017-03-01
# 3      2017-03-02
# 4      2017-03-03
#           ...
# 1255   2022-02-18
# 1256   2022-02-22
# 1257   2022-02-23
# 1258   2022-02-24
# 1259   2022-02-25
# Name: Date, Length: 1260, dtype: datetime64[ns]

# %%
## If we want to make date column as index again we can do that-
df_testla.set_index('Date')
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...                ...         ...         ...         ...         ...
# 2022-02-18  886.869995  837.609985  886.000000  856.979980  22710500.0
# 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#              Adj Close
# Date
# 2017-02-27   49.245998
# 2017-02-28   49.998001
# 2017-03-01   50.004002
# ...

# %%
## A quick function to check how to calculate the time taken by a function to execute
def check_time():
    start_time=datetime.now()
    sum=1
    print(f"Function started on {start_time}")
    for i in range(1,15,1):
          sum=sum*i
    print(f"the sum ={sum}")
              
          
    end_time=datetime.now()
    print(f"Function ended on {end_time}")     
    print(f"The total time taken to execute the function is {end_time-start_time}")

# %%
check_time()
# Out:
# Function started on 2022-02-27 12:30:26.561576
# the sum =87178291200
# Function ended on 2022-02-27 12:30:26.562572
# The total time taken to execute the function is 0:00:00.000996

# %% [markdown]
# ## Time resampling

# %%
df_testla.head()
# Out:
#         Date       High        Low       Open      Close      Volume  \
# 0 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0
# 1 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0
# 2 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0
# 3 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0
# 4 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0
#
#    Adj Close
# 0  49.245998
# 1  49.998001
# 2  50.004002
# 3  50.096001
# 4  50.313999

# %%
df_tesla=df_testla.set_index('Date')
df_tesla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0  49.245998
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999

# %%
df_tesla.resample(rule='A').min() ## This shows the min values of all the features for each year. rule= A will resample data on yearly basis
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-12-31   49.299999   48.402000   48.838001   48.737999  14597000.0
# 2018-12-31   52.066002   48.917999   50.556000   50.112000  15403500.0
# 2019-12-31   37.335999   35.397999   36.220001   35.793999  12328000.0
# 2020-12-31   80.972000   70.101997   74.940002   72.244003  17357700.0
# 2021-12-31  566.210022  539.489990  552.549988  563.000000   9800600.0
# 2022-12-31  802.479980  700.000000  700.390015  764.039978  16909700.0
#
#              Adj Close
# Date
# 2017-12-31   48.737999
# 2018-12-31   50.112000
# 2019-12-31   35.793999
# 2020-12-31   72.244003
# 2021-12-31  563.000000
# 2022-12-31  764.039978

# %%
df_tesla.resample(rule='B').min()   ##Rule=B stands for Business days
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...                ...         ...         ...         ...         ...
# 2022-02-21         NaN         NaN         NaN         NaN         NaN
# 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#              Adj Close
# Date
# 2017-02-27   49.245998
# 2017-02-28   49.998001
# 2017-03-01   50.004002
# ...

# %%
df_tesla.resample(rule='C').min()     ## Rule C stands for custom business day
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-02-27   49.672001   48.402000   49.633999   49.245998  57304000.0
# 2017-02-28   50.200001   48.779999   48.838001   49.998001  30390500.0
# 2017-03-01   50.970001   49.821999   50.835999   50.004002  24047500.0
# 2017-03-02   50.655998   49.653999   49.942001   50.096001  16759000.0
# 2017-03-03   50.380001   49.799999   50.147999   50.313999  14597000.0
# ...                ...         ...         ...         ...         ...
# 2022-02-21         NaN         NaN         NaN         NaN         NaN
# 2022-02-22  856.729980  801.099976  834.130005  821.530029  27762700.0
# 2022-02-23  835.299988  760.559998  830.429993  764.039978  31752300.0
# 2022-02-24  802.479980  700.000000  700.390015  800.770020  45107400.0
# 2022-02-25  819.500000  782.400024  809.229980  809.869995  25309500.0
#
#              Adj Close
# Date
# 2017-02-27   49.245998
# 2017-02-28   49.998001
# 2017-03-01   50.004002
# ...

# %%
df_tesla.resample(rule='W').min() ## Rule W stands for week
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-03-05   49.672001   48.402000   48.838001   49.245998  14597000.0
# 2017-03-12   49.299999   48.599998   49.242001   48.737999  15331500.0
# 2017-03-19   49.369999   48.556000   48.964001   49.234001  15113000.0
# 2017-03-26   51.014000   50.048000   50.312000   50.136002  16601000.0
# 2017-04-02   54.113998   51.950001   52.119999   54.043999  16473000.0
# ...                ...         ...         ...         ...         ...
# 2022-01-30  857.500000  792.010010  831.559998  829.099976  28865300.0
# 2022-02-06  931.500000  862.049988  872.710022  891.140015  22264300.0
# 2022-02-13  915.960022  850.700012  905.530029  860.000000  16909700.0
# 2022-02-20  886.869995  837.609985  861.570007  856.979980  17098100.0
# 2022-02-27  802.479980  700.000000  700.390015  764.039978  25309500.0
#
#              Adj Close
# Date
# 2017-03-05   49.245998
# 2017-03-12   48.737999
# 2017-03-19   49.234001
# ...

# %%
df_tesla.resample(rule='M').min()     ## Rule M stands for calender MOnth end
# Out:
#                    High         Low         Open        Close      Volume  \
# Date
# 2017-02-28    49.672001   48.402000    48.838001    49.245998  30390500.0
# 2017-03-31    49.299999   48.556000    48.964001    48.737999  14597000.0
# 2017-04-30    59.799999   56.916000    57.380001    59.000000  15178500.0
# 2017-05-31    61.554001   58.152000    59.599998    59.091999  20608000.0
# 2017-06-30    68.575996   66.842003    67.699997    67.970001  24616000.0
# ...                 ...         ...          ...          ...         ...
# 2021-10-31   780.780029  763.590027   776.200012   775.219971  12247200.0
# 2021-11-30  1031.979980  978.599976  1003.309998  1013.390015  11680900.0
# 2021-12-31   921.690002  886.119995   910.700012   899.940002  13577900.0
# 2022-01-31   857.500000  792.010010   831.559998   829.099976  22021100.0
# 2022-02-28   802.479980  700.000000   700.390015   764.039978  16909700.0
#
#               Adj Close
# Date
# 2017-02-28    49.245998
# ...

# %%
### Now let's try to plot some information regarding Maximum open price on yearly basis and then on monthly basis
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla.resample(rule='M').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## We can have rule=QS for quaterly 
df_tesla.resample(rule='QS').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## Let's use subplots to plot these observations
figure, ax=plt.subplots(1,3, figsize=(20,5))
figure.suptitle("A graph between Max open vs the number")
ax[0].plot(df_tesla.resample(rule='M').max()['Open'])
ax[0].set_title('Monthly Max Open')
ax[1].plot(df_tesla.resample(rule='Y').max()['Open'])
ax[1].set_title('Yearly Max Open')
ax[2].plot(df_tesla.resample(rule='QS').max()['Open'])
ax[2].set_title('Quaterly Max Open')
# Out:
# Text(0.5, 1.0, 'Quaterly Max Open')

# %%
figure, ax=plt.subplots(1,3, figsize=(20,5))
figure.suptitle("A graph between Max High vs the number")
ax[0].plot(df_tesla.resample(rule='M').max()['High'])
ax[0].set_title('Monthly Max High')
ax[1].plot(df_tesla.resample(rule='Y').max()['High'])
ax[1].set_title('Yearly Max High')
ax[2].plot(df_tesla.resample(rule='QS').max()['High'])
ax[2].set_title('Quaterly Max High')
# Out:
# Text(0.5, 1.0, 'Quaterly Max High')

# %%
figure, ax=plt.subplots(1,3, figsize=(20,5))
figure.suptitle("A graph between Max Low vs the number")
ax[0].plot(df_tesla.resample(rule='M').max()['Low'])
ax[0].set_title('Monthly Max Low')
ax[1].plot(df_tesla.resample(rule='Y').max()['Low'])
ax[1].set_title('Yearly Max Low')
ax[2].plot(df_tesla.resample(rule='QS').max()['Low'])
ax[2].set_title('Quaterly Max Low')
# Out:
# Text(0.5, 1.0, 'Quaterly Max Low')

# %%
## Now Let's see the bar plots 
df_tesla.resample(rule='A').max()['Open'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').mean().plot(kind='bar', figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='QS').mean().plot(kind='bar', figsize=(20,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Rolling and smoothing

# %%
df_tesla['High'].rolling(11).max().head(20)
# Out:
# Date
# 2017-02-27          NaN
# 2017-02-28          NaN
# 2017-03-01          NaN
# 2017-03-02          NaN
# 2017-03-03          NaN
# 2017-03-06          NaN
# 2017-03-07          NaN
# 2017-03-08          NaN
# 2017-03-09          NaN
# 2017-03-10          NaN
# 2017-03-13    50.970001
# 2017-03-14    51.624001
# 2017-03-15    52.200001
# 2017-03-16    53.150002
# 2017-03-17    53.150002
# 2017-03-20    53.150002
# 2017-03-21    53.150002
# 2017-03-22    53.150002
# 2017-03-23    53.150002
# 2017-03-24    53.150002
# Name: High, dtype: float64

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(40)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2017-02-27  49.672001  48.402000  49.633999  49.245998  57304000.0  49.245998
# 2017-02-28  50.200001  48.779999  48.838001  49.998001  30390500.0  49.998001
# 2017-03-01  50.970001  49.821999  50.835999  50.004002  24047500.0  50.004002
# 2017-03-02  50.655998  49.653999  49.942001  50.096001  16759000.0  50.096001
# 2017-03-03  50.380001  49.799999  50.147999  50.313999  14597000.0  50.313999
# 2017-03-06  50.340000  49.501999  49.582001  50.242001  16777500.0  50.242001
# 2017-03-07  50.778000  49.664001  50.383999  49.717999  17297500.0  49.717999
# 2017-03-08  50.014000  49.063999  49.400002  49.374001  18626000.0  49.374001
# 2017-03-09  49.731998  48.599998  49.526001  48.980000  19396500.0  48.980000
# 2017-03-10  49.299999  48.599998  49.242001  48.737999  15331500.0  48.737999
# 2017-03-13  49.369999  48.556000  48.964001  49.234001  15113000.0  49.234001
# ...

# %%
## Let's try to plot open vs the new column
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### On the above plot we can see that orange line starts after some point of blue line because it has some Nan values due to ROLLING. This yellow line is termed as smoothing, because we have smoothened the too much zig zag of blue line with the help of yellow line by taking the mean.
